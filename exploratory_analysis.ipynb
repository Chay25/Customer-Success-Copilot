# %% [markdown]
# # AI Customer Success Copilot - Exploratory Analysis
#
# This notebook is a placeholder for analyzing customer tickets, sentiment trends, churn risk distribution, and upsell opportunities.

# %%
import pandas as pd

df = pd.read_csv('../data/sample_tickets.csv')
df.head()
